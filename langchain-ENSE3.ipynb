# %%
# %pip install PyPDF2

# %%
# importing required modules
from PyPDF2 import PdfReader
# creating a pdf reader object
reader = PdfReader('/content/ddd.pdf')

# printing number of pages in pdf file
print(len(reader.pages))

# getting a specific page from the pdf file
page = reader.pages[0]

# extracting text from page
text = page.extract_text()
print(text)
# Out:
# 17
# TO-247 long leads TO-247123 123Features
# • Maximum junction temperature: T J = 175 °C
# • High speed switching series
# • Minimized tail current
# • V CE(sat)  = 2.1 V (typ.) @ I C = 25 A
# • 5 μs minimum short circuit withstand time at T J = 150 °C
# • Safe paralleling
# • Low thermal resistance
# • Very fast recovery antiparallel diode
# Applications
# •Photovoltaic inverters
# •Uninterruptible power supply
# •Welding
# •Power factor correction
# •High frequency converters
# Description
# This device is an IGBT developed using an advanced proprietary trench gate field-
# stop structure. The device is part of the H series of IGBTs, which represents an
# optimum compromise between conduction and switching losses to maximize the
# efficiency of high-switching frequency converters. Furthermore, a slightly positive
# VCE(sat)  temperature coefficient and very tight parameter distribution result in safer
# paralleling operation.
# Product status links
# STGW25H120DF2
# ...

# %% [markdown]
# ***Documents***An object that holds a piece of text and metadata (more information about that text)It is useful when a quick specified data need to be extracted.https://python.langchain.com/docs/integrations/document_transformers/openai_metadata_tagger

# %%
# %pip install openai

# %%
# %pip install langchain

# %%
openai_api_key = "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"

# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_transformers.openai_functions import create_metadata_tagger
from langchain.schema import Document

# %%
llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613", openai_api_key=openai_api_key)
schema = {
    "type": "object",
    "properties": {
        "section": {"type": "string"},
        "datasheet_title": {"type": "string"},
        "specification": {"type": "string"},
        "product parameters": {},
        "Product status links": {"type": "string"},
    },
    "required": ["section", "datasheet_title", "specification", "product parameters", "Product status links"]
}

# Assuming create_metadata_tagger is a function that uses the schema and llm to create a metadata tagger
document_transformer = create_metadata_tagger(metadata_schema=schema, llm=llm)

# %%
original_documents = [
    Document(
        page_content=text)
]

enhanced_documents = document_transformer.transform_documents(original_documents)

# %%
import json

def format_metadata(d):
    return json.dumps(d.metadata)

# Call the function for each document and join the results
formatted_metadata = "\n\n---------------\n\n".join(format_metadata(d) for d in enhanced_documents)

# Now you can use the 'formatted_metadata' variable whenever needed
print(formatted_metadata)
# Out:
# {"section": "Passage", "datasheet_title": "DS9297 - Rev 5 - March 2021", "specification": "Trench gate field-stop IGBT, H series 1200 V, 25 A high speed", "product parameters": {"Maximum junction temperature": "T J = 175 \u00b0C", "V CE(sat)": "2.1 V (typ.) @ I C = 25 A", "Minimum short circuit withstand time": "5 \u03bcs minimum short circuit withstand time at T J = 150 \u00b0C", "Safe paralleling": "Yes", "Low thermal resistance": "Yes", "Very fast recovery antiparallel diode": "Yes"}, "Product status links": "STGW25H120DF2, STGWA25H120DF2"}

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage

chat = ChatOpenAI(temperature=0, openai_api_key=openai_api_key)

# %%
x = chat(
    [
        SystemMessage(content="You are a nice AI chat bot to help Electrical Engineers in selecting the right component for their circuits and recommendation. Accordingly, we need a fine tuned model for being an effective assistance. Based on the following information, provide me several samples to be trained based on this format of dictionary with message as key and sentences as values, and provide me in several sentences please. Also, for each sentence provide the product status link(name and type)"),
        HumanMessage(content=formatted_metadata)
    ]
)

# %%
x
# Out:
# AIMessage(content='1. The DS9297 datasheet provides information on the STGW25H120DF2 and STGWA25H120DF2, which are trench gate field-stop IGBTs from the H series. These components have a voltage rating of 1200 V and a current rating of 25 A, making them suitable for high-speed applications.\n\n2. The maximum junction temperature for these IGBTs is 175 °C, ensuring reliable operation even under high-temperature conditions. \n\n3. With a VCE(sat) of 2.1 V (typical) at a current of 25 A, these IGBTs offer low on-state voltage drop, minimizing power losses in the circuit.\n\n4. The STGW25H120DF2 and STGWA25H120DF2 IGBTs have a minimum short circuit withstand time of 5 μs at a junction temperature of 150 °C, making them robust and capable of handling short circuit conditions.\n\n5. These IGBTs support safe paralleling, allowing multiple devices to be connected in parallel for increased current handling capability.\n\n6. The STGW25H120DF2 and STGWA25H120DF2 IGBTs feature low thermal resist
# ...

# %%
x
# Out:
# AIMessage(content='1. The DS9297 datasheet provides information on the STGW25H120DF2 and STGWA25H120DF2, which are trench gate field-stop IGBTs from the H series. These components have a voltage rating of 1200 V and a current rating of 25 A, making them suitable for high-speed applications.\n\n2. The maximum junction temperature for these IGBTs is 175 °C, ensuring reliable operation even under high-temperature conditions. \n\n3. With a VCE(sat) of 2.1 V (typical) at a current of 25 A, these IGBTs offer low on-state voltage drop, minimizing power losses in the circuit.\n\n4. The STGW25H120DF2 and STGWA25H120DF2 IGBTs have a minimum short circuit withstand time of 5 μs at a junction temperature of 150 °C, making them robust and capable of handling short circuit conditions.\n\n5. These IGBTs support safe paralleling, allowing multiple devices to be connected in parallel for increased current handling capability.\n\n6. The STGW25H120DF2 and STGWA25H120DF2 IGBTs feature low thermal resist
# ...

# %%
y = x.content.split('\n\n')

# %%
par = []
for i in y:
  par.append({'message': i})

# %%
par
# Out:
# [{'message': '1. The DS9297 datasheet provides information on the STGW25H120DF2 and STGWA25H120DF2, which are trench gate field-stop IGBTs from the H series. These components have a voltage rating of 1200 V and a current rating of 25 A, making them suitable for high-speed applications.'},
#  {'message': '2. The maximum junction temperature for these IGBTs is 175 °C, ensuring reliable operation even under high-temperature conditions. '},
#  {'message': '3. With a VCE(sat) of 2.1 V (typical) at a current of 25 A, these IGBTs offer low on-state voltage drop, minimizing power losses in the circuit.'},
#  {'message': '4. The STGW25H120DF2 and STGWA25H120DF2 IGBTs have a minimum short circuit withstand time of 5 μs at a junction temperature of 150 °C, making them robust and capable of handling short circuit conditions.'},
#  {'message': '5. These IGBTs support safe paralleling, allowing multiple devices to be connected in parallel for increased current handling capability.'},
# ...

# %%
print(par[0]['message'])
# Out:
# 1. The datasheet titled "Datasheet" provides information about a Trench gate field-stop IGBT, H series with a voltage rating of 1200 V and a current rating of 25 A.

# %%
#Let's save the json file

# %%
import json

# Your list
my_list = par

# Specify the file path where you want to save the JSON file
file_path = '/content/drive/MyDrive/Mobin/LLM-Mobin/ENSE3-Schenider/data'

# Write the list to a JSON file
with open(file_path, 'w') as json_file:
    json.dump(my_list, json_file)
